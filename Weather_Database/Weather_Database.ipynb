# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 809

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | schleswig
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | karachi
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | pisco
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | adrar
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | alice springs
# Processing Record 12 of Set 1 | cidreira
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | mildura
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | cayenne
# Processing Record 18 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | codrington
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | labrea
# Processing Record 24 of Set 1 | olafsvik
# Processing Record 25 of Set 1 | gayeri
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 1 | tilichiki
# Processing Record 29 of Set 1 | kurilsk
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | ponta pora
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | namibe
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | aklavik
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | banepa
# Processing Record 41 of Set 1 | aksarka
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | carballo
# Processing Record 46 of Set 1 | tongchuan
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | teeli
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | salalah
# Processing Record 1 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 2 | lagoa
# Processing Record 3 of Set 2 | ballina
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | maniitsoq
# Processing Record 6 of Set 2 | geraldton
# Processing Record 7 of Set 2 | lebu
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | yulara
# Processing Record 10 of Set 2 | joensuu
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | klaksvik
# Processing Record 13 of Set 2 | kulunda
# Processing Record 14 of Set 2 | kudahuvadhoo
# Processing Record 15 of Set 2 | sola
# Processing Record 16 of Set 2 | maragogi
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | kruisfontein
# Processing Record 20 of Set 2 | isangel
# Processing Record 21 of Set 2 | orocue
# Processing Record 22 of Set 2 | broken hill
# Processing Record 23 of Set 2 | puerto madryn
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | havre-saint-pierre
# Processing Record 27 of Set 2 | hamilton
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | aland
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | albany
# Processing Record 32 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | bengkulu
# Processing Record 35 of Set 2 | bilibino
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | mantua
# Processing Record 38 of Set 2 | basco
# Processing Record 39 of Set 2 | poli
# Processing Record 40 of Set 2 | amalapuram
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | atkarsk
# Processing Record 43 of Set 2 | burkhala
# City not found. Skipping...
# Processing Record 44 of Set 2 | tuy hoa
# Processing Record 45 of Set 2 | hithadhoo
# Processing Record 46 of Set 2 | sao joao da barra
# Processing Record 47 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 2 | narasannapeta
# Processing Record 49 of Set 2 | antalaha
# Processing Record 50 of Set 2 | ostrovnoy
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | meulaboh
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | gusau
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | stephenville
# Processing Record 8 of Set 3 | srednekolymsk
# Processing Record 9 of Set 3 | gotha
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | acarau
# Processing Record 13 of Set 3 | marsh harbour
# Processing Record 14 of Set 3 | port macquarie
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | beringovskiy
# Processing Record 17 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 18 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | verkhnyaya inta
# Processing Record 21 of Set 3 | tucuma
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | atar
# Processing Record 25 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 3 | mezen
# Processing Record 27 of Set 3 | broome
# Processing Record 28 of Set 3 | kavaratti
# Processing Record 29 of Set 3 | victoria
# Processing Record 30 of Set 3 | yeppoon
# Processing Record 31 of Set 3 | bolshiye uki
# City not found. Skipping...
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | waterloo
# Processing Record 35 of Set 3 | vao
# Processing Record 36 of Set 3 | ciceu-giurgesti
# Processing Record 37 of Set 3 | tanout
# Processing Record 38 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 3 | mbini
# Processing Record 40 of Set 3 | laviana
# Processing Record 41 of Set 3 | karratha
# Processing Record 42 of Set 3 | usinsk
# Processing Record 43 of Set 3 | vaitape
# Processing Record 44 of Set 3 | vuktyl
# Processing Record 45 of Set 3 | talara
# Processing Record 46 of Set 3 | sayat
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | kutum
# Processing Record 49 of Set 3 | finschhafen
# Processing Record 50 of Set 3 | itaituba
# Processing Record 1 of Set 4 | malindi
# Processing Record 2 of Set 4 | pedernales
# Processing Record 3 of Set 4 | mahebourg
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | gambiran
# Processing Record 6 of Set 4 | russell
# Processing Record 7 of Set 4 | olinda
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | tavda
# Processing Record 10 of Set 4 | luanda
# Processing Record 11 of Set 4 | warrensburg
# Processing Record 12 of Set 4 | mpanda
# Processing Record 13 of Set 4 | airai
# Processing Record 14 of Set 4 | eirunepe
# Processing Record 15 of Set 4 | gaoual
# Processing Record 16 of Set 4 | port blair
# Processing Record 17 of Set 4 | poum
# Processing Record 18 of Set 4 | minot
# Processing Record 19 of Set 4 | talnakh
# Processing Record 20 of Set 4 | kodiak
# Processing Record 21 of Set 4 | mehamn
# Processing Record 22 of Set 4 | takoradi
# Processing Record 23 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 4 | dingle
# Processing Record 25 of Set 4 | pachino
# Processing Record 26 of Set 4 | zhigansk
# Processing Record 27 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 4 | ballstad
# City not found. Skipping...
# Processing Record 29 of Set 4 | oriximina
# Processing Record 30 of Set 4 | hovd
# Processing Record 31 of Set 4 | urengoy
# Processing Record 32 of Set 4 | biak
# Processing Record 33 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 34 of Set 4 | izberbash
# Processing Record 35 of Set 4 | puerto narino
# Processing Record 36 of Set 4 | merritt
# Processing Record 37 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 4 | tazovskiy
# Processing Record 39 of Set 4 | kloulklubed
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | cherskiy
# Processing Record 42 of Set 4 | isabela
# Processing Record 43 of Set 4 | henties bay
# Processing Record 44 of Set 4 | mingaora
# Processing Record 45 of Set 4 | saint george
# Processing Record 46 of Set 4 | aberdeen
# Processing Record 47 of Set 4 | temyasovo
# Processing Record 48 of Set 4 | trairi
# Processing Record 49 of Set 4 | kampong thum
# Processing Record 50 of Set 4 | harrogate
# Processing Record 1 of Set 5 | kayerkan
# Processing Record 2 of Set 5 | nelson bay
# Processing Record 3 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | mizan teferi
# Processing Record 7 of Set 5 | bathsheba
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | rupert
# Processing Record 10 of Set 5 | san quintin
# Processing Record 11 of Set 5 | bukan
# Processing Record 12 of Set 5 | ponazyrevo
# Processing Record 13 of Set 5 | wanxian
# Processing Record 14 of Set 5 | hilo
# Processing Record 15 of Set 5 | orchard homes
# Processing Record 16 of Set 5 | alta floresta
# Processing Record 17 of Set 5 | dongsheng
# Processing Record 18 of Set 5 | pevek
# Processing Record 19 of Set 5 | jurilovca
# Processing Record 20 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 5 | severo-kurilsk
# Processing Record 22 of Set 5 | paamiut
# Processing Record 23 of Set 5 | provideniya
# Processing Record 24 of Set 5 | port lincoln
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | nioro
# Processing Record 27 of Set 5 | mabaruma
# Processing Record 28 of Set 5 | palmer
# Processing Record 29 of Set 5 | lorengau
# Processing Record 30 of Set 5 | praia da vitoria
# Processing Record 31 of Set 5 | beidao
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | gisors
# Processing Record 34 of Set 5 | udomlya
# Processing Record 35 of Set 5 | mustasaari
# Processing Record 36 of Set 5 | xai-xai
# Processing Record 37 of Set 5 | seymchan
# Processing Record 38 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 5 | saint-philippe
# Processing Record 40 of Set 5 | ulladulla
# Processing Record 41 of Set 5 | itarema
# Processing Record 42 of Set 5 | cururupu
# Processing Record 43 of Set 5 | buenos aires
# Processing Record 44 of Set 5 | longyearbyen
# Processing Record 45 of Set 5 | taoudenni
# Processing Record 46 of Set 5 | oyama
# Processing Record 47 of Set 5 | verkhnyaya balkariya
# Processing Record 48 of Set 5 | cap malheureux
# Processing Record 49 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 50 of Set 5 | eyl
# Processing Record 1 of Set 6 | belmonte
# Processing Record 2 of Set 6 | mirnyy
# Processing Record 3 of Set 6 | dalbandin
# Processing Record 4 of Set 6 | khandyga
# Processing Record 5 of Set 6 | bud
# Processing Record 6 of Set 6 | powell river
# Processing Record 7 of Set 6 | naryan-mar
# Processing Record 8 of Set 6 | contamana
# Processing Record 9 of Set 6 | am timan
# Processing Record 10 of Set 6 | la ronge
# Processing Record 11 of Set 6 | staszow
# Processing Record 12 of Set 6 | ndele
# Processing Record 13 of Set 6 | okmulgee
# Processing Record 14 of Set 6 | oistins
# Processing Record 15 of Set 6 | tammisaari
# Processing Record 16 of Set 6 | manadhoo
# Processing Record 17 of Set 6 | arraial do cabo
# Processing Record 18 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 6 | ola
# Processing Record 20 of Set 6 | maceio
# Processing Record 21 of Set 6 | khislavichi
# Processing Record 22 of Set 6 | nizhniy kuranakh
# Processing Record 23 of Set 6 | hyeres
# Processing Record 24 of Set 6 | noumea
# Processing Record 25 of Set 6 | slave lake
# Processing Record 26 of Set 6 | raudeberg
# Processing Record 27 of Set 6 | upernavik
# Processing Record 28 of Set 6 | qrendi
# Processing Record 29 of Set 6 | darhan
# Processing Record 30 of Set 6 | williston
# Processing Record 31 of Set 6 | sitka
# Processing Record 32 of Set 6 | tikapur
# Processing Record 33 of Set 6 | puerto escondido
# Processing Record 34 of Set 6 | aonla
# Processing Record 35 of Set 6 | manggar
# Processing Record 36 of Set 6 | sangar
# Processing Record 37 of Set 6 | rabo de peixe
# Processing Record 38 of Set 6 | adana
# Processing Record 39 of Set 6 | talcahuano
# Processing Record 40 of Set 6 | stokmarknes
# Processing Record 41 of Set 6 | san patricio
# Processing Record 42 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 6 | besancon
# Processing Record 44 of Set 6 | hobyo
# Processing Record 45 of Set 6 | kainantu
# Processing Record 46 of Set 6 | ginir
# Processing Record 47 of Set 6 | mukhen
# Processing Record 48 of Set 6 | iralaya
# Processing Record 49 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 50 of Set 6 | hami
# Processing Record 1 of Set 7 | katsuura
# Processing Record 2 of Set 7 | lunenburg
# Processing Record 3 of Set 7 | monrovia
# Processing Record 4 of Set 7 | chimbote
# Processing Record 5 of Set 7 | wynyard
# Processing Record 6 of Set 7 | sorong
# Processing Record 7 of Set 7 | harindanga
# Processing Record 8 of Set 7 | eckernforde
# Processing Record 9 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 7 | mwinilunga
# Processing Record 12 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 7 | leisure city
# Processing Record 14 of Set 7 | los llanos de aridane
# Processing Record 15 of Set 7 | lahat
# Processing Record 16 of Set 7 | batagay-alyta
# Processing Record 17 of Set 7 | baykit
# Processing Record 18 of Set 7 | havoysund
# Processing Record 19 of Set 7 | iqaluit
# Processing Record 20 of Set 7 | kahului
# Processing Record 21 of Set 7 | salinopolis
# Processing Record 22 of Set 7 | pemberton
# Processing Record 23 of Set 7 | nangomba
# Processing Record 24 of Set 7 | coihaique
# Processing Record 25 of Set 7 | fremont
# Processing Record 26 of Set 7 | bang mun nak
# Processing Record 27 of Set 7 | loukhi
# Processing Record 28 of Set 7 | achacachi
# Processing Record 29 of Set 7 | burns lake
# Processing Record 30 of Set 7 | coahuayana
# Processing Record 31 of Set 7 | dwarka
# Processing Record 32 of Set 7 | boden
# Processing Record 33 of Set 7 | auki
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | appleton
# Processing Record 36 of Set 7 | tinskoy
# Processing Record 37 of Set 7 | san salvo
# Processing Record 38 of Set 7 | khairagarh
# Processing Record 39 of Set 7 | mount gambier
# Processing Record 40 of Set 7 | borba
# Processing Record 41 of Set 7 | satipo
# Processing Record 42 of Set 7 | los andes
# Processing Record 43 of Set 7 | biltine
# Processing Record 44 of Set 7 | mandera
# Processing Record 45 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 7 | lahij
# Processing Record 47 of Set 7 | vila velha
# Processing Record 48 of Set 7 | dalvik
# Processing Record 49 of Set 7 | santiago del estero
# Processing Record 50 of Set 7 | stornoway
# Processing Record 1 of Set 8 | sorland
# Processing Record 2 of Set 8 | ambon
# Processing Record 3 of Set 8 | muros
# Processing Record 4 of Set 8 | lasa
# Processing Record 5 of Set 8 | setubal
# Processing Record 6 of Set 8 | ocos
# Processing Record 7 of Set 8 | arman
# Processing Record 8 of Set 8 | alyangula
# Processing Record 9 of Set 8 | tawang
# Processing Record 10 of Set 8 | faanui
# Processing Record 11 of Set 8 | hope
# Processing Record 12 of Set 8 | buraydah
# Processing Record 13 of Set 8 | belize
# Processing Record 14 of Set 8 | marawi
# Processing Record 15 of Set 8 | trinidad
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | yerbogachen
# Processing Record 18 of Set 8 | imbituba
# Processing Record 19 of Set 8 | metro
# Processing Record 20 of Set 8 | nabire
# Processing Record 21 of Set 8 | mahibadhoo
# Processing Record 22 of Set 8 | agropoli
# Processing Record 23 of Set 8 | porto velho
# Processing Record 24 of Set 8 | jalor
# Processing Record 25 of Set 8 | billings
# Processing Record 26 of Set 8 | bac lieu
# Processing Record 27 of Set 8 | chumikan
# Processing Record 28 of Set 8 | rafai
# Processing Record 29 of Set 8 | balikpapan
# Processing Record 30 of Set 8 | merauke
# Processing Record 31 of Set 8 | bethel
# Processing Record 32 of Set 8 | goya
# Processing Record 33 of Set 8 | neiafu
# Processing Record 34 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 8 | never
# Processing Record 36 of Set 8 | ribeira grande
# Processing Record 37 of Set 8 | obera
# Processing Record 38 of Set 8 | ous
# Processing Record 39 of Set 8 | marsa matruh
# Processing Record 40 of Set 8 | tonj
# Processing Record 41 of Set 8 | ust-nera
# Processing Record 42 of Set 8 | vorotynets
# Processing Record 43 of Set 8 | clacton-on-sea
# Processing Record 44 of Set 8 | west richland
# Processing Record 45 of Set 8 | odweyne
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | north battleford
# Processing Record 48 of Set 8 | ust-kuyga
# Processing Record 49 of Set 8 | livingston
# Processing Record 50 of Set 8 | chulym
# Processing Record 1 of Set 9 | rensvik
# Processing Record 2 of Set 9 | lavrentiya
# Processing Record 3 of Set 9 | khandbari
# Processing Record 4 of Set 9 | half moon bay
# Processing Record 5 of Set 9 | nyurba
# Processing Record 6 of Set 9 | kavieng
# Processing Record 7 of Set 9 | sechura
# Processing Record 8 of Set 9 | kangaatsiaq
# Processing Record 9 of Set 9 | waipawa
# Processing Record 10 of Set 9 | hurghada
# Processing Record 11 of Set 9 | qeshm
# Processing Record 12 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 14 of Set 9 | pangai
# Processing Record 15 of Set 9 | strezhevoy
# Processing Record 16 of Set 9 | nanortalik
# Processing Record 17 of Set 9 | guajara-mirim
# City not found. Skipping...
# Processing Record 18 of Set 9 | nanakuli
# Processing Record 19 of Set 9 | yangjiang
# Processing Record 20 of Set 9 | gladstone
# Processing Record 21 of Set 9 | port moresby
# Processing Record 22 of Set 9 | teluknaga
# Processing Record 23 of Set 9 | carauari
# Processing Record 24 of Set 9 | cascais
# Processing Record 25 of Set 9 | ponta do sol
# Processing Record 26 of Set 9 | kharan
# Processing Record 27 of Set 9 | hornepayne
# Processing Record 28 of Set 9 | catamarca
# Processing Record 29 of Set 9 | duz
# City not found. Skipping...
# Processing Record 30 of Set 9 | burg
# Processing Record 31 of Set 9 | alofi
# Processing Record 32 of Set 9 | sioux lookout
# Processing Record 33 of Set 9 | kalmunai
# Processing Record 34 of Set 9 | nome
# Processing Record 35 of Set 9 | rocha
# Processing Record 36 of Set 9 | celendin
# Processing Record 37 of Set 9 | lisakovsk
# Processing Record 38 of Set 9 | avanigadda
# Processing Record 39 of Set 9 | stykkisholmur
# Processing Record 40 of Set 9 | buchanan
# Processing Record 41 of Set 9 | flinders
# Processing Record 42 of Set 9 | shellbrook
# Processing Record 43 of Set 9 | cabo san lucas
# Processing Record 44 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 9 | nogales
# Processing Record 46 of Set 9 | minab
# Processing Record 47 of Set 9 | znamenskoye
# Processing Record 48 of Set 9 | terme
# Processing Record 49 of Set 9 | rongcheng
# Processing Record 50 of Set 9 | cabedelo
# Processing Record 1 of Set 10 | yicheng
# Processing Record 2 of Set 10 | qorveh
# Processing Record 3 of Set 10 | timra
# Processing Record 4 of Set 10 | aripuana
# Processing Record 5 of Set 10 | mokhsogollokh
# Processing Record 6 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 7 of Set 10 | fairbanks
# Processing Record 8 of Set 10 | arklow
# Processing Record 9 of Set 10 | adeje
# Processing Record 10 of Set 10 | vanimo
# Processing Record 11 of Set 10 | gorgan
# Processing Record 12 of Set 10 | morondava
# Processing Record 13 of Set 10 | kasiri
# Processing Record 14 of Set 10 | jaisalmer
# Processing Record 15 of Set 10 | husavik
# Processing Record 16 of Set 10 | benguela
# Processing Record 17 of Set 10 | diapaga
# Processing Record 18 of Set 10 | kadoma
# Processing Record 19 of Set 10 | namwala
# Processing Record 20 of Set 10 | bhadra
# Processing Record 21 of Set 10 | rawson
# Processing Record 22 of Set 10 | korla
# Processing Record 23 of Set 10 | barcelos
# Processing Record 24 of Set 10 | agadez
# Processing Record 25 of Set 10 | plainview
# Processing Record 26 of Set 10 | miri
# Processing Record 27 of Set 10 | stavern
# Processing Record 28 of Set 10 | jiaozuo
# Processing Record 29 of Set 10 | belozerskoye
# Processing Record 30 of Set 10 | torbay
# Processing Record 31 of Set 10 | atambua
# Processing Record 32 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 10 | khasan
# Processing Record 34 of Set 10 | aliwal north
# Processing Record 35 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 36 of Set 10 | killybegs
# Processing Record 37 of Set 10 | richards bay
# Processing Record 38 of Set 10 | launceston
# Processing Record 39 of Set 10 | vestmannaeyjar
# Processing Record 40 of Set 10 | pangnirtung
# Processing Record 41 of Set 10 | anloga
# Processing Record 42 of Set 10 | maloyaz
# City not found. Skipping...
# Processing Record 43 of Set 10 | souillac
# Processing Record 44 of Set 10 | ancud
# Processing Record 45 of Set 10 | asmara
# Processing Record 46 of Set 10 | hurricane
# Processing Record 47 of Set 10 | archidona
# Processing Record 48 of Set 10 | gao
# Processing Record 49 of Set 10 | tartki
# City not found. Skipping...
# Processing Record 50 of Set 10 | etawah
# Processing Record 1 of Set 11 | awbari
# Processing Record 2 of Set 11 | dolores
# Processing Record 3 of Set 11 | tomatlan
# Processing Record 4 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 11 | honiara
# Processing Record 6 of Set 11 | caravelas
# Processing Record 7 of Set 11 | turayf
# Processing Record 8 of Set 11 | saint anthony
# Processing Record 9 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 11 | itoman
# Processing Record 11 of Set 11 | gafanha da encarnacao
# Processing Record 12 of Set 11 | ahuimanu
# Processing Record 13 of Set 11 | banda aceh
# Processing Record 14 of Set 11 | akdepe
# Processing Record 15 of Set 11 | tiznit
# Processing Record 16 of Set 11 | tahta
# Processing Record 17 of Set 11 | baleshwar
# Processing Record 18 of Set 11 | iskateley
# Processing Record 19 of Set 11 | yumen
# Processing Record 20 of Set 11 | san cristobal
# Processing Record 21 of Set 11 | dhing
# Processing Record 22 of Set 11 | lata
# Processing Record 23 of Set 11 | santa flavia
# Processing Record 24 of Set 11 | teahupoo
# Processing Record 25 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 11 | gazanjyk
# Processing Record 27 of Set 11 | lang suan
# Processing Record 28 of Set 11 | sao jose da coroa grande
# Processing Record 29 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 11 | vostok
# Processing Record 31 of Set 11 | vila franca do campo
# Processing Record 32 of Set 11 | akyab
# Processing Record 33 of Set 11 | ribeira brava
# Processing Record 34 of Set 11 | isla del bosque
# Processing Record 35 of Set 11 | yarmouth
# Processing Record 36 of Set 11 | pareora
# Processing Record 37 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 38 of Set 11 | prince rupert
# Processing Record 39 of Set 11 | plastun
# Processing Record 40 of Set 11 | lincoln
# Processing Record 41 of Set 11 | samarai
# Processing Record 42 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 43 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 11 | peniche
# Processing Record 45 of Set 11 | paz de ariporo
# City not found. Skipping...
# Processing Record 46 of Set 11 | novoagansk
# Processing Record 47 of Set 11 | lagodekhi
# Processing Record 48 of Set 11 | baisha
# Processing Record 49 of Set 11 | calamar
# Processing Record 50 of Set 11 | alencon
# Processing Record 1 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 12 | nakama
# Processing Record 3 of Set 12 | gat
# Processing Record 4 of Set 12 | esso
# Processing Record 5 of Set 12 | bayanday
# Processing Record 6 of Set 12 | buin
# Processing Record 7 of Set 12 | mahenge
# Processing Record 8 of Set 12 | pacifica
# Processing Record 9 of Set 12 | quang ngai
# Processing Record 10 of Set 12 | kulhudhuffushi
# Processing Record 11 of Set 12 | clarksville
# Processing Record 12 of Set 12 | kutoarjo
# Processing Record 13 of Set 12 | yanam
# Processing Record 14 of Set 12 | kousseri
# Processing Record 15 of Set 12 | deputatskiy
# Processing Record 16 of Set 12 | faya
# Processing Record 17 of Set 12 | sulangan
# Processing Record 18 of Set 12 | ust-omchug
# Processing Record 19 of Set 12 | havelock
# Processing Record 20 of Set 12 | uyuni
# Processing Record 21 of Set 12 | rio de janeiro
# Processing Record 22 of Set 12 | conde
# Processing Record 23 of Set 12 | orneta
# Processing Record 24 of Set 12 | mariinsk
# Processing Record 25 of Set 12 | ligourion
# Processing Record 26 of Set 12 | letnyaya stavka
# Processing Record 27 of Set 12 | evora
# Processing Record 28 of Set 12 | chara
# Processing Record 29 of Set 12 | bela
# Processing Record 30 of Set 12 | dekar
# Processing Record 31 of Set 12 | aleksandrovka
# Processing Record 32 of Set 12 | changchun
# Processing Record 33 of Set 12 | varberg
# Processing Record 34 of Set 12 | akhmeta
# Processing Record 35 of Set 12 | labuhan
# Processing Record 36 of Set 12 | bayeux
# Processing Record 37 of Set 12 | hay river
# Processing Record 38 of Set 12 | celestun
# Processing Record 39 of Set 12 | khokhryaki
# Processing Record 40 of Set 12 | cockburn town
# Processing Record 41 of Set 12 | hokitika
# Processing Record 42 of Set 12 | bintulu
# Processing Record 43 of Set 12 | saint-joseph
# Processing Record 44 of Set 12 | hanna
# Processing Record 45 of Set 12 | loutra
# Processing Record 46 of Set 12 | storslett
# Processing Record 47 of Set 12 | ovre ardal
# Processing Record 48 of Set 12 | yangambi
# Processing Record 49 of Set 12 | tari
# Processing Record 50 of Set 12 | champerico
# Processing Record 1 of Set 13 | gamboma
# Processing Record 2 of Set 13 | bontang
# Processing Record 3 of Set 13 | muroto
# Processing Record 4 of Set 13 | muhos
# Processing Record 5 of Set 13 | kailua
# Processing Record 6 of Set 13 | ca mau
# Processing Record 7 of Set 13 | marion
# Processing Record 8 of Set 13 | quzhou
# Processing Record 9 of Set 13 | ivanovka
# Processing Record 10 of Set 13 | zamora
# Processing Record 11 of Set 13 | dinguiraye
# Processing Record 12 of Set 13 | lundazi
# Processing Record 13 of Set 13 | gubkinskiy
# Processing Record 14 of Set 13 | altamont
# Processing Record 15 of Set 13 | ucluelet
# Processing Record 16 of Set 13 | bukama
# Processing Record 17 of Set 13 | denpasar
# Processing Record 18 of Set 13 | morant bay
# Processing Record 19 of Set 13 | virginia beach
# Processing Record 20 of Set 13 | chimichagua
# Processing Record 21 of Set 13 | oyon
# Processing Record 22 of Set 13 | nerang
# Processing Record 23 of Set 13 | bethanien
# Processing Record 24 of Set 13 | ilebo
# Processing Record 25 of Set 13 | boddam
# Processing Record 26 of Set 13 | roald
# Processing Record 27 of Set 13 | yaring
# Processing Record 28 of Set 13 | sinnamary
# Processing Record 29 of Set 13 | aksu
# Processing Record 30 of Set 13 | lukovetskiy
# Processing Record 31 of Set 13 | solnechnyy
# Processing Record 32 of Set 13 | vrangel
# Processing Record 33 of Set 13 | bad soden-salmunster
# Processing Record 34 of Set 13 | omboue
# Processing Record 35 of Set 13 | shache
# Processing Record 36 of Set 13 | sungaipenuh
# Processing Record 37 of Set 13 | manokwari
# Processing Record 38 of Set 13 | pemangkat
# Processing Record 39 of Set 13 | pinar del rio
# Processing Record 40 of Set 13 | cortez
# Processing Record 41 of Set 13 | tynda
# Processing Record 42 of Set 13 | pochutla
# Processing Record 43 of Set 13 | almeirim
# Processing Record 44 of Set 13 | opportunity
# Processing Record 45 of Set 13 | atasu
# Processing Record 46 of Set 13 | pitimbu
# Processing Record 47 of Set 13 | saint-francois
# Processing Record 48 of Set 13 | antofagasta
# Processing Record 49 of Set 13 | kondinskoye
# Processing Record 50 of Set 13 | batagay
# Processing Record 1 of Set 14 | zdvinsk
# Processing Record 2 of Set 14 | nevers
# Processing Record 3 of Set 14 | santa fe
# Processing Record 4 of Set 14 | boa vista
# Processing Record 5 of Set 14 | leua
# Processing Record 6 of Set 14 | bakal
# Processing Record 7 of Set 14 | noyabrsk
# Processing Record 8 of Set 14 | vahan
# Processing Record 9 of Set 14 | la palma
# Processing Record 10 of Set 14 | berdigestyakh
# Processing Record 11 of Set 14 | ranong
# Processing Record 12 of Set 14 | lagunas
# Processing Record 13 of Set 14 | inhambane
# Processing Record 14 of Set 14 | comodoro rivadavia
# Processing Record 15 of Set 14 | makakilo city
# Processing Record 16 of Set 14 | grand gaube
# Processing Record 17 of Set 14 | amazar
# Processing Record 18 of Set 14 | storforshei
# Processing Record 19 of Set 14 | coquimbo
# Processing Record 20 of Set 14 | kudeyevskiy
# Processing Record 21 of Set 14 | choucheng
# City not found. Skipping...
# Processing Record 22 of Set 14 | puerto gaitan
# Processing Record 23 of Set 14 | srivardhan
# Processing Record 24 of Set 14 | seydi
# Processing Record 25 of Set 14 | jamkhed
# Processing Record 26 of Set 14 | piedra gorda
# Processing Record 27 of Set 14 | mancio lima
# Processing Record 28 of Set 14 | blackwater
# Processing Record 29 of Set 14 | turbat
# Processing Record 30 of Set 14 | marrakesh
# Processing Record 31 of Set 14 | bandundu
# Processing Record 32 of Set 14 | hofn
# Processing Record 33 of Set 14 | saint-augustin
# Processing Record 34 of Set 14 | nouadhibou
# Processing Record 35 of Set 14 | juneau
# Processing Record 36 of Set 14 | steinbach
# Processing Record 37 of Set 14 | ndola
# Processing Record 38 of Set 14 | aykhal
# Processing Record 39 of Set 14 | agadir
# Processing Record 40 of Set 14 | corinto
# Processing Record 41 of Set 14 | teya
# Processing Record 42 of Set 14 | antipovka
# Processing Record 43 of Set 14 | panama city
# Processing Record 44 of Set 14 | tura
# Processing Record 45 of Set 14 | ierapetra
# Processing Record 46 of Set 14 | port augusta
# Processing Record 47 of Set 14 | eichstatt
# Processing Record 48 of Set 14 | palauig
# Processing Record 49 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 50 of Set 14 | baijiantan
# Processing Record 1 of Set 15 | grand baie
# Processing Record 2 of Set 15 | baraboo
# Processing Record 3 of Set 15 | chapais
# Processing Record 4 of Set 15 | burnie
# Processing Record 5 of Set 15 | yambio
# Processing Record 6 of Set 15 | victoria point
# Processing Record 7 of Set 15 | bay roberts
# Processing Record 8 of Set 15 | pauini
# Processing Record 9 of Set 15 | sistranda
# Processing Record 10 of Set 15 | darab
# Processing Record 11 of Set 15 | kaduqli
# Processing Record 12 of Set 15 | neijiang
# Processing Record 13 of Set 15 | cache creek
# Processing Record 14 of Set 15 | amuntai
# Processing Record 15 of Set 15 | alihe
# Processing Record 16 of Set 15 | tuburan
# Processing Record 17 of Set 15 | eastleigh
# Processing Record 18 of Set 15 | tommot
# Processing Record 19 of Set 15 | muskogee
# Processing Record 20 of Set 15 | neryungri
# Processing Record 21 of Set 15 | okhotsk
# Processing Record 22 of Set 15 | port shepstone
# Processing Record 23 of Set 15 | vanino
# Processing Record 24 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 15 | sfantu gheorghe
# Processing Record 26 of Set 15 | ginda
# Processing Record 27 of Set 15 | altamira
# Processing Record 28 of Set 15 | khrustalnyy
# City not found. Skipping...
# Processing Record 29 of Set 15 | port-gentil
# Processing Record 30 of Set 15 | poronaysk
# Processing Record 31 of Set 15 | kamaishi
# Processing Record 32 of Set 15 | soe
# Processing Record 33 of Set 15 | haines junction
# Processing Record 34 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 15 | dingzhou
# Processing Record 36 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 15 | ilulissat
# Processing Record 38 of Set 15 | shitkino
# Processing Record 39 of Set 15 | karasjok
# Processing Record 40 of Set 15 | menongue
# Processing Record 41 of Set 15 | luau
# Processing Record 42 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 43 of Set 15 | atbasar
# Processing Record 44 of Set 15 | casper
# Processing Record 45 of Set 15 | abu dhabi
# Processing Record 46 of Set 15 | arkhangelos
# City not found. Skipping...
# Processing Record 47 of Set 15 | bafra
# Processing Record 48 of Set 15 | vila
# Processing Record 49 of Set 15 | igrim
# Processing Record 50 of Set 15 | sigerfjord
# City not found. Skipping...
# Processing Record 1 of Set 16 | ojinaga
# Processing Record 2 of Set 16 | namatanai
# Processing Record 3 of Set 16 | ladario
# Processing Record 4 of Set 16 | wang saphung
# Processing Record 5 of Set 16 | ugoofaaru
# Processing Record 6 of Set 16 | ampanihy
# Processing Record 7 of Set 16 | dunda
# Processing Record 8 of Set 16 | camacha
# Processing Record 9 of Set 16 | nyaunglebin
# Processing Record 10 of Set 16 | nizhnekamsk
# Processing Record 11 of Set 16 | vidosi
# Processing Record 12 of Set 16 | ossora
# Processing Record 13 of Set 16 | floirac
# Processing Record 14 of Set 16 | leskovac
# Processing Record 15 of Set 16 | chadan
# Processing Record 16 of Set 16 | marystown
# Processing Record 17 of Set 16 | general teran
# Processing Record 18 of Set 16 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 16 | hualmay
# Processing Record 20 of Set 16 | bulungu
# Processing Record 21 of Set 16 | tambura
# Processing Record 22 of Set 16 | clyde river
# Processing Record 23 of Set 16 | sweetwater
# Processing Record 24 of Set 16 | raychikhinsk
# Processing Record 25 of Set 16 | chihuahua
# Processing Record 26 of Set 16 | barranca
# Processing Record 27 of Set 16 | batemans bay
# Processing Record 28 of Set 16 | yeletskiy
# City not found. Skipping...
# Processing Record 29 of Set 16 | wembley
# Processing Record 30 of Set 16 | cabinda
# Processing Record 31 of Set 16 | mangai
# Processing Record 32 of Set 16 | margate
# Processing Record 33 of Set 16 | kyren
# Processing Record 34 of Set 16 | sembe
# Processing Record 35 of Set 16 | melbu
# Processing Record 36 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 16 | saint-pierre
# Processing Record 38 of Set 16 | bandarbeyla
# Processing Record 39 of Set 16 | aleksandrovskoye
# Processing Record 40 of Set 16 | roma
# Processing Record 41 of Set 16 | olga
# Processing Record 42 of Set 16 | narsaq
# Processing Record 43 of Set 16 | melito di porto salvo
# Processing Record 44 of Set 16 | yantzaza
# Processing Record 45 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 16 | umtata
# Processing Record 47 of Set 16 | anadyr
# Processing Record 48 of Set 16 | kosonsoy
# Processing Record 49 of Set 16 | phan thiet
# Processing Record 50 of Set 16 | evensk
# Processing Record 1 of Set 17 | salekhard
# Processing Record 2 of Set 17 | khor
# Processing Record 3 of Set 17 | bonfim
# Processing Record 4 of Set 17 | port-cartier
# Processing Record 5 of Set 17 | preobrazheniye
# Processing Record 6 of Set 17 | biysk
# Processing Record 7 of Set 17 | agva
# City not found. Skipping...
# Processing Record 8 of Set 17 | nakhon phanom
# Processing Record 9 of Set 17 | luderitz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 742

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Schleswig      DE  54.5167    9.5500     70.79        84          80
# 1      Thompson      CA  55.7435  -97.8558     62.76        42          20
# 2       Rikitea      PF -23.1203 -134.9692     70.65        67          38
# 3       Ushuaia      AR -54.8000  -68.3000     37.06        75          40
# 4       Karachi      PK  24.9056   67.0822     84.02        79          75
# 5         Bluff      NZ -46.6000  168.3333     46.80        87         100
# 6         Pisco      PE -13.7000  -76.2167     66.25        72           0
# 7   Tuktoyaktuk      CA  69.4541 -133.0374     48.20        93          90
# 8         Adrar      MR  20.5022  -10.0711    100.99         7          17
# 9  Punta Arenas      CL -53.1500  -70.9167     41.11        60           0
#
#    Wind Speed Current Description
# 0        8.05       broken clouds
# 1       10.36          few clouds
# 2        6.42    scattered clouds
# 3       20.71    scattered clouds
# 4       18.41       broken clouds
# 5        4.81       moderate rain
# 6        9.22           clear sky
# 7       17.27          light rain
# 8        8.79          few clouds
# 9       14.97           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
